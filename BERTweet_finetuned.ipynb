# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, ParameterGrid
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from transformers import AutoModelForSequenceClassification
from transformers import TrainingArguments
import numpy as np
import evaluate
from transformers import TrainingArguments, Trainer
from transformers import AutoTokenizer
from datasets import Dataset
from transformers import TextClassificationPipeline

# %%
dfo = pd.read_csv('data/obama_cleaned.csv')
dfo = dfo.rename(columns={'tweets' : 'text', 'class' : 'label'})
dfr = pd.read_csv('data/romney_cleaned.csv')
dfr = dfr.rename(columns={'tweets' : 'text', 'class' : 'label'})
df = pd.concat([dfo, dfr], ignore_index = True)
df.info()
pd.set_option('display.max_rows', None)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11271 entries, 0 to 11270
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    11271 non-null  object
#  1   label   11271 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 176.2+ KB

# %%
df = df.astype({'text' : 'string'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11271 entries, 0 to 11270
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    11271 non-null  string
#  1   label   11271 non-null  int64
# dtypes: int64(1), string(1)
# memory usage: 176.2 KB

# %% [markdown]
# # Pre-trained model: BERTweet

# %% [markdown]
# Fine-tuning using our data:

# %%
Xo0 = dfo['text']
yo0 = dfo['label'].map({1 : 2, 0 : 1, -1 : 0})
Xo, Xo_test, yo, yo_test = train_test_split(Xo0, yo0, test_size = 0.2, random_state = 27)
Xo_train, Xo_eval, yo_train, yo_eval = train_test_split(Xo, yo, test_size = 0.25, random_state = 27)
Xr0 = dfr['text']
yr0 = dfr['label'].map({1 : 2, 0 : 1, -1 : 0})
Xr, Xr_test, yr, yr_test = train_test_split(Xr0, yr0, test_size = 0.2, random_state = 27)
Xr_train, Xr_eval, yr_train, yr_eval = train_test_split(Xr, yr, test_size = 0.25, random_state = 27)


traindf_o = pd.concat([Xo_train,yo_train], axis = 1)
traindf_r = pd.concat([Xr_train,yr_train], axis = 1)
evaldf_o = pd.concat([Xo_eval,yo_eval], axis = 1)
evaldf_r = pd.concat([Xr_eval,yr_eval], axis = 1)
testdf_o = pd.concat([Xo_test,yo_test], axis = 1)
testdf_r = pd.concat([Xr_test,yr_test], axis = 1)

# %%
train_o = Dataset.from_pandas(traindf_o, split = 'train')
eval_o = Dataset.from_pandas(evaldf_o, split = 'eval')
test_o = Dataset.from_pandas(testdf_o, split = 'test')
train_r = Dataset.from_pandas(traindf_r, split = 'train')
eval_r = Dataset.from_pandas(evaldf_r, split = 'eval')
test_r = Dataset.from_pandas(testdf_r, split = 'test')

# %%
tokenizer = AutoTokenizer.from_pretrained("finiteautomata/bertweet-base-sentiment-analysis")


def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True)
    

tokenized_train_o = train_o.map(tokenize_function, batched=True)
tokenized_eval_o = eval_o.map(tokenize_function, batched=True)
tokenized_test_o = test_o.map(tokenize_function, batched=True)
tokenized_train_r = train_r.map(tokenize_function, batched=True)
tokenized_eval_r = eval_o.map(tokenize_function, batched=True)
tokenized_test_r = test_r.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/3374 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1125 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1125 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3387 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1125 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1130 [00:00<?, ? examples/s]

# %%
model_o = AutoModelForSequenceClassification.from_pretrained("finiteautomata/bertweet-base-sentiment-analysis", num_labels=3)
metric = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

training_args_o = TrainingArguments(output_dir="checkpoints/test_trainer_o", evaluation_strategy="epoch", num_train_epochs=2)
trainer_o = Trainer(
    model=model_o,
    args=training_args_o,
    train_dataset=tokenized_train_o,
    eval_dataset=tokenized_eval_o,
    compute_metrics=compute_metrics,
)

trainer_o.train()
# Out:
#     <div>
#
#       <progress value='844' max='844' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [844/844 07:44, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.735206</td>
#       <td>0.702222</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.765500</td>
#       <td>0.783975</td>
#       <td>0.711111</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=844, training_loss=0.6470462925626204, metrics={'train_runtime': 465.6619, 'train_samples_per_second': 14.491, 'train_steps_per_second': 1.812, 'total_flos': 443872335707136.0, 'train_loss': 0.6470462925626204, 'epoch': 2.0})

# %%
trainer_o.save_model('models/model_obama')

# %%
model_r = AutoModelForSequenceClassification.from_pretrained("finiteautomata/bertweet-base-sentiment-analysis", num_labels=3)

metric = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

training_args_r = TrainingArguments(output_dir="checkpoints/test_trainer_r", evaluation_strategy="epoch", num_train_epochs=3)
trainer_r = Trainer(
    model=model_r,
    args=training_args_r,
    train_dataset=tokenized_train_r,
    eval_dataset=tokenized_eval_r,
    compute_metrics=compute_metrics,
)

trainer_r.train()
# Out:
#     <div>
#
#       <progress value='1272' max='1272' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1272/1272 14:45, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.109888</td>
#       <td>0.496889</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.803200</td>
#       <td>1.178195</td>
#       <td>0.551111</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.502900</td>
#       <td>1.480066</td>
#       <td>0.600000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1272, training_loss=0.5905224062361807, metrics={'train_runtime': 886.4822, 'train_samples_per_second': 11.462, 'train_steps_per_second': 1.435, 'total_flos': 668373859383552.0, 'train_loss': 0.5905224062361807, 'epoch': 3.0})

# %%
trainer_r.save_model('models/model_romney')

# %% [markdown]
# # Load from checkpoints

# %%
model_o = AutoModelForSequenceClassification.from_pretrained("checkpoints/test_trainer_o/checkpoint-1000", num_labels=3)
metric = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

training_args_o = TrainingArguments(output_dir="checkpoints/test_trainer_o", evaluation_strategy="epoch", num_train_epochs=5)
trainer_o = Trainer(
    model=model_o,
    args=training_args_o,
    train_dataset=tokenized_train_o,
    eval_dataset=tokenized_eval_o,
    compute_metrics=compute_metrics,
)

trainer_o.train()

# %%
trainer_o.save_model('models/model_obama')

# %%
model_r = AutoModelForSequenceClassification.from_pretrained("checkpoints/test_trainer_r/checkpoint-1000", num_labels=3)

metric = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

training_args_r = TrainingArguments(output_dir="checkpoints/test_trainer_r", evaluation_strategy="epoch", num_train_epochs=5)
trainer_r = Trainer(
    model=model_r,
    args=training_args_r,
    train_dataset=tokenized_train_r,
    eval_dataset=tokenized_eval_r,
    compute_metrics=compute_metrics,
)

trainer_r.train()

# %%
trainer_r.save_model('models/model_romney')

# %% [markdown]
# # Load finetuned models

# %%
model_o = AutoModelForSequenceClassification.from_pretrained('models/model_obama')
model_r = AutoModelForSequenceClassification.from_pretrained('models/model_romney')

# %%
pipe_o = TextClassificationPipeline(model=model_o, tokenizer=tokenizer)
pipe_r = TextClassificationPipeline(model=model_r, tokenizer=tokenizer)

# %%
pos = list()
neg = list()
neu = list()
pred_o = pd.DataFrame()
for t in test_o['text']:
    pred = pipe_o(t, top_k=None)
    for l in pred:
        if l['label'] == 'POS':
            pos.append(l['score'])
            
        elif l['label'] == 'NEG':
            neg.append(l['score'])
          
        else: 
            neu.append(l['score'])
            

pred_o['pos'] = pos
pred_o['neg'] = neg
pred_o['neu'] = neu

# %%
pred_o['class'] = list(map({0 : -1, 1 : 0, 2 : 1}.get, test_o['label']))

# %%
pos = list()
neg = list()
neu = list()
pred_r = pd.DataFrame()
for t in test_r['text']:
    pred = pipe_r(t, top_k=None)
    for l in pred:
        if l['label'] == 'POS':
            pos.append(l['score'])
        elif l['label'] == 'NEG':
            neg.append(l['score'])
        else: 
            neu.append(l['score'])

pred_r['pos'] = pos
pred_r['neg'] = neg
pred_r['neu'] = neu

# %%
pred_r['class'] = list(map({0 : -1, 1 : 0, 2 : 1}.get, test_r['label']))

# %% [markdown]
# # Predict label using maximum probability

# %%
def pred_label(df):
    preds = list()
    for idx, row in df.iterrows():
        if row['pos'] >= row['neu'] and row['pos'] >= row['neg']:
            preds.append(1)
        elif row['neg'] >= row['neu'] and row['neg'] > row['pos']:
            preds.append(-1)
        elif row['neu'] > row['pos'] and row['neu'] > row['neg']:
            preds.append(0)
    df['pred'] = preds
    acc = accuracy_score(df['class'], df['pred'])
    prec = precision_score(df['class'], df['pred'], average = None, zero_division = np.nan)
    rec = recall_score(df['class'], df['pred'], average = None)
    f1 = f1_score(df['class'], df['pred'], average = None)
    print("Accuracy:", acc)
    print("Precision:", prec)
    print("Recall:", rec)
    print("F1:", f1)
    return df

# %%
predicted_labels_o = pred_label(pred_o)
# Out:
# Accuracy: 0.7288888888888889
# Precision: [0.72093023 0.66917293 0.80825959]
# Recall: [0.73614776 0.68286445 0.77183099]
# F1: [0.72845953 0.67594937 0.78962536]

# %%
predicted_labels_r = pred_label(pred_r)
# Out:
# Accuracy: 0.7176991150442478
# Precision: [0.74516129 0.67128028 0.70135747]
# Recall: [0.83544304 0.52291105 0.75242718]
# F1: [0.78772379 0.58787879 0.72599532]

# %%
predicted_labels_o['pred'].value_counts()
# Out:
#  0    399
# -1    387
#  1    339
# Name: pred, dtype: int64

# %%
predicted_labels_r['pred'].value_counts()
# Out:
# -1    620
#  0    289
#  1    221
# Name: pred, dtype: int64

# %% [markdown]
# # Predict label using ML models

# %%
def test_model(model, parameters, X, y, n_splits):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state = 27)
    avg_accuracies = list()
    avg_precisions = list()
    avg_recalls = list()
    avg_f1s = list()
    confs = list()
    for conf in ParameterGrid(parameters):
        print('Testing', conf)
        accuracies = list()
        precisions = list()
        recalls = list()
        f1s = list()
        i = 1
        for train_index, test_index in kf.split(X):
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]
            try:
                model.set_params(**conf)
                model.fit(X_train, y_train)
            except:
                print('Skipped', conf)
                break
            print('\tFold', i, 'of', n_splits)
            y_pred = model.predict(X_test)
            accuracies.append(accuracy_score(y_test, y_pred))
            precisions.append(precision_score(y_test, y_pred, average=None, zero_division = np.nan))
            recalls.append(recall_score(y_test, y_pred, average=None, zero_division = np.nan))
            f1s.append(f1_score(y_test, y_pred, average=None, zero_division = np.nan))
            if i == 1:
                confs.append(conf)
            i = i + 1
            
    
        if len(accuracies) != 0:  
            avg_accuracies.append(sum(accuracies)/len(accuracies))
            avg_precisions.append((sum(precisions)/len(precisions)) if len(precisions) > 0 else np.nan)
            avg_recalls.append(sum(recalls)/len(recalls) if len(recalls) > 0 else np.nan)
            avg_f1s.append(sum(f1s)/len(f1s) if len(f1s) > 0 else np.nan)
        
    results = {'Parameters' : confs,
              'Accuracy' : avg_accuracies,
              'Precision' : avg_precisions,
              'Recall' : avg_recalls,
              'F1' : avg_f1s}
    
    return pd.DataFrame.from_dict(results)

# %%
Xo = predicted_labels_o[['pos', 'neg', 'neu']]
yo = predicted_labels_o['class']
Xo_train, Xo_test, yo_train, yo_test = train_test_split(Xo, yo, test_size = 0.2)

Xr = predicted_labels_r[['pos', 'neg', 'neu']]
yr = predicted_labels_r['class']
Xr_train, Xr_test, yr_train, yr_test = train_test_split(Xr, yr, test_size = 0.2)

# %%
params_svm = {'C' : (0.1, 1, 10, 100),
             'kernel' : ('rbf', 'poly', 'linear', 'sigmoid'),
             'gamma' : ('scale', 'auto')}
svm = SVC()
svm_results_o = test_model(svm, params_svm, Xo_train, yo_train, 4)
# Out:
# Testing {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4

# %%
svm_results_o
# Out:
#                                            Parameters  Accuracy  \
# 0       {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}  0.716667
# 1      {'C': 0.1, 'gamma': 'scale', 'kernel': 'poly'}  0.715556
# 2    {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}  0.712222
# 3   {'C': 0.1, 'gamma': 'scale', 'kernel': 'sigmoid'}  0.718889
# 4        {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}  0.713333
# 5       {'C': 0.1, 'gamma': 'auto', 'kernel': 'poly'}  0.370000
# 6     {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}  0.712222
# 7    {'C': 0.1, 'gamma': 'auto', 'kernel': 'sigmoid'}  0.714444
# 8         {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}  0.717778
# 9        {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}  0.723333
# 10     {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}  0.717778
# 11    {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}  0.678889
# 12         {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}  0.716667
# 13        {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}  0.704444
# 14      {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}  0.717778
# 15     {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}  0.715556
# 16       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}  0.718889
# 17      {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}  0.718889
# 18    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}  0.718889
# 19   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}  0.621111
# 20        {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}  0.722222
# 21       {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}  0.705556
# 22     {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}  0.718889
# 23    {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}  0.713333
# 24      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}  0.718889
# 25     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}  0.718889
# 26   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}  0.718889
# 27  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}  0.607778
# 28       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}  0.717778
# 29      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}  0.724444
# 30    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}  0.718889
# 31   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}  0.706667
#
#                                             Precision  \
# 0   [0.7292874965606811, 0.6432898496851985, 0.798...
# 1   [0.7321517236151383, 0.6457036079577385, 0.790...
# 2   [0.7357288819407573, 0.6272415979708307, 0.803...
# 3   [0.7322322143750715, 0.6406484257871063, 0.810...
# 4   [0.7325513492695874, 0.6328598778274535, 0.802...
# 5                                     [nan, nan, nan]
# 6   [0.7357288819407573, 0.6272415979708307, 0.803...
# 7   [0.7290932159039265, 0.6346229795301905, 0.805...
# 26  [0.7230824817415926, 0.7012797619047619, 0.731...
# 27  [0.655112143768311, 0.515625, 0.6597017045454545]
# 28  [0.7370890982239231, 0.6426488095238095, 0.776...
# 29  [0.7393316231408666, 0.6651785714285714, 0.770...
# 30  [0.7230824817415926, 0.7012797619047619, 0.731...
# 31  [0.8295118942484264, 0.5938690476190476, 0.693...
#
#                                                    F1
# 0   [0.7224676750506649, 0.6660443189899791, 0.766...
# 1   [0.7217016392355758, 0.6629211235021967, 0.767...
# 2   [0.7284650691658211, 0.6600307295254968, 0.754...
# 3   [0.7359194618299592, 0.6670389624887882, 0.757...
# 4   [0.7254489338679205, 0.6631606121269179, 0.756...
# 5                                     [nan, nan, nan]
# 6   [0.7284650691658211, 0.6600307295254968, 0.754...
# 7   [0.7271208249147072, 0.6628924162257496, 0.758...
# 8   [0.7281947229278358, 0.6505131257373549, 0.774...
# 9   [0.7343448820206048, 0.662192267242816, 0.7726...
# 10  [0.7284650691658211, 0.6670481259702816, 0.762...
# 11  [0.6852335039051981, 0.6303333239811366, 0.730...
# 12  [0.7252966080395363, 0.6612781770050473, 0.767...
# 13  [0.7234941335400578, 0.6607804742338641, 0.740...
# 14  [0.7284650691658211, 0.6670481259702816, 0.762...
# 15  [0.7272585292268868, 0.66292027623916, 0.76121...
# 16  [0.7280838843769879, 0.6467974567289635, 0.779...
# 17  [0.7295857919970495, 0.6519934386432604, 0.773...
# 18  [0.7284650691658211, 0.6681024929666777, 0.764...
# 19  [0.6355727221482034, 0.5206022408963585, 0.715...
# 20  [0.7313436943500081, 0.6513991760875749, 0.783...
# 21  [0.7135756306167089, 0.660425397132398, 0.7542...
# 22  [0.7284650691658211, 0.6681024929666777, 0.764...
# 23  [0.7294496240500306, 0.6613584971589137, 0.755...
# 24  [0.7292979480910515, 0.646468931395402, 0.7773...
# 25  [0.7285259165033634, 0.6538656946281198, 0.772...
# 26  [0.7284650691658211, 0.6681024929666777, 0.764...
# 27  [0.6227974902082045, 0.4934908441467577, 0.711...
# 28  [0.7259014433784385, 0.6512918890445722, 0.775...
# 29  [0.7332701554651091, 0.6636009095756463, 0.776...
# 30  [0.7284650691658211, 0.6681024929666777, 0.764...
# 31  [0.7285737337639159, 0.6297326363342377, 0.757...

# %%
svm_r = SVC()
svm_results_r = test_model(svm_r, params_svm, Xr_train, yr_train, 4)
# Out:
# Testing {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4

# %%
svm_results_r
# Out:
#                                            Parameters  Accuracy  \
# 0       {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}  0.706858
# 1      {'C': 0.1, 'gamma': 'scale', 'kernel': 'poly'}  0.705752
# 2    {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}  0.709071
# 3   {'C': 0.1, 'gamma': 'scale', 'kernel': 'sigmoid'}  0.711283
# 4        {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'}  0.706858
# 5       {'C': 0.1, 'gamma': 'auto', 'kernel': 'poly'}  0.487832
# 6     {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'}  0.709071
# 7    {'C': 0.1, 'gamma': 'auto', 'kernel': 'sigmoid'}  0.709071
# 8         {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}  0.706858
# 9        {'C': 1, 'gamma': 'scale', 'kernel': 'poly'}  0.706858
# 10     {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}  0.709071
# 11    {'C': 1, 'gamma': 'scale', 'kernel': 'sigmoid'}  0.685841
# 12         {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}  0.706858
# 13        {'C': 1, 'gamma': 'auto', 'kernel': 'poly'}  0.707965
# 14      {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}  0.709071
# 15     {'C': 1, 'gamma': 'auto', 'kernel': 'sigmoid'}  0.709071
# 16       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}  0.705752
# 17      {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}  0.705752
# 18    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}  0.709071
# 19   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}  0.667035
# 20        {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}  0.705752
# 21       {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}  0.706858
# 22     {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}  0.709071
# 23    {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}  0.703540
# 24      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}  0.702434
# 25     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}  0.704646
# 26   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}  0.709071
# 27  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}  0.633850
# 28       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}  0.707965
# 29      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}  0.704646
# 30    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}  0.709071
# 31   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}  0.676991
#
#                                             Precision  \
# 0   [0.7368487100021192, 0.655128205128205, 0.6924...
# 1   [0.7383763959010375, 0.635770013568521, 0.7113...
# 2   [0.7382635722068435, 0.6603183119263909, 0.691...
# 3   [0.7422558316404394, 0.6656161172350364, 0.688...
# 4   [0.7368487100021192, 0.6561149883682286, 0.690...
# 5                     [0.48783185840707965, nan, nan]
# 6   [0.7382635722068435, 0.6603183119263909, 0.691...
# 7   [0.737348021296885, 0.6615794692425455, 0.6918...
# 8   [0.7333760852848562, 0.660413623967437, 0.6924...
# 9   [0.7332735920548414, 0.660066913013083, 0.6924...
# 10  [0.7382635722068435, 0.6603183119263909, 0.691...
# 11  [0.744540471555854, 0.6040628864158275, 0.7318...
# 12  [0.7333760852848562, 0.660413623967437, 0.6924...
# 13  [0.7422817996923015, 0.6394827815657431, 0.711...
# 14  [0.7382635722068435, 0.6603183119263909, 0.691...
# 15  [0.7394962967016001, 0.659137428347619, 0.6918...
# 16  [0.730867729771963, 0.6628026409074796, 0.6889...
# 17  [0.7309619200244201, 0.6604312354312354, 0.692...
# 18  [0.7382635722068435, 0.6603183119263909, 0.691...
# 19  [0.7314753320683112, 0.5759309385225012, 0.736...
# 20  [0.7304316265273104, 0.654365228912996, 0.7019...
# 21  [0.7463679302594011, 0.6305775568683788, 0.709...
# 22  [0.7382635722068435, 0.6603183119263909, 0.691...
# 23  [0.7379306815235486, 0.6474348706505372, 0.686...
# 24  [0.7262477785855649, 0.6614461258391171, 0.686...
# 25  [0.7288971287550834, 0.6631194074742461, 0.688...
# 26  [0.7382635722068435, 0.6603183119263909, 0.691...
# 27  [0.703835508827392, 0.5046435421994885, 0.7063...
# 28  [0.7330009138588685, 0.664661615266454, 0.6924...
# 29  [0.7332735920548414, 0.6526700149127846, 0.691...
# 30  [0.7382635722068435, 0.6603183119263909, 0.691...
# 17  [0.7790685045336866, 0.5721534820159782, 0.704...
# 18  [0.7821320913497644, 0.5763392099507207, 0.709...
# 19  [0.7390520821214741, 0.5516683200976593, 0.660...
# 20  [0.7797009253165502, 0.574430956311929, 0.6999...
# 21  [0.7834724420819476, 0.5832624552998528, 0.694...
# 22  [0.7821320913497644, 0.5763392099507207, 0.709...
# 23  [0.7778159031601675, 0.5752563544086735, 0.698...
# 24  [0.779124510114467, 0.5606000391395325, 0.6980...
# 25  [0.7788720143728081, 0.5732326187066257, 0.695...
# 26  [0.7821320913497644, 0.5763392099507207, 0.709...
# 27  [0.7144290159026323, 0.4980453786605377, 0.643...
# 28  [0.7812345072388837, 0.5761116323904083, 0.704...
# 29  [0.7813471993144823, 0.5714153189660655, 0.694...
# 30  [0.7821320913497644, 0.5763392099507207, 0.709...
# 31  [0.7618146691673883, 0.49936672891835937, 0.65...

# %%
params_rf = {'n_estimators' : (50, 100, 150),
            'criterion' : ('entropy', 'gini'),
            'max_features' : (None, 'sqrt')}
rf = RandomForestClassifier()
rf_results_o = test_model(rf, params_rf, Xo_train, yo_train, 4)
# Out:
# Testing {'criterion': 'entropy', 'max_features': None, 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': None, 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': None, 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': None, 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': None, 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': None, 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4

# %%
rf_results_o
# Out:
#                                            Parameters  Accuracy  \
# 0   {'criterion': 'entropy', 'max_features': None,...  0.644444
# 1   {'criterion': 'entropy', 'max_features': None,...  0.656667
# 2   {'criterion': 'entropy', 'max_features': None,...  0.638889
# 3   {'criterion': 'entropy', 'max_features': 'sqrt...  0.655556
# 4   {'criterion': 'entropy', 'max_features': 'sqrt...  0.656667
# 5   {'criterion': 'entropy', 'max_features': 'sqrt...  0.657778
# 6   {'criterion': 'gini', 'max_features': None, 'n...  0.647778
# 7   {'criterion': 'gini', 'max_features': None, 'n...  0.652222
# 8   {'criterion': 'gini', 'max_features': None, 'n...  0.644444
# 9   {'criterion': 'gini', 'max_features': 'sqrt', ...  0.645556
# 10  {'criterion': 'gini', 'max_features': 'sqrt', ...  0.652222
# 11  {'criterion': 'gini', 'max_features': 'sqrt', ...  0.654444
#
#                                             Precision  \
# 0   [0.6698928886428887, 0.588768814476577, 0.6783...
# 1   [0.6744050033806627, 0.5899498182392919, 0.713...
# 2   [0.6608131286298613, 0.5737938596491228, 0.686...
# 3   [0.6668915099187994, 0.6032261870623938, 0.703...
# 4   [0.6669767732267733, 0.610122076331507, 0.6932...
# 5   [0.6692234350743805, 0.6028242784669338, 0.705...
# 6   [0.6676470588235294, 0.5882057856943701, 0.689...
# 7   [0.6688290357313506, 0.5951774398323884, 0.696...
# 8   [0.6661260186841582, 0.5827203425229741, 0.690...
# 9   [0.6479546338689888, 0.5960365853658537, 0.695...
# 10  [0.6736648183277397, 0.5947626197626198, 0.689...
# 11  [0.6678868645973909, 0.5975892188184599, 0.703...
#
#                                                Recall  \
# 0   [0.6850643424870684, 0.576875, 0.6700662878787...
# 1   [0.6943004331553052, 0.5936011904761904, 0.683...
# 2   [0.676085832036671, 0.5733333333333333, 0.6683...
# 3   [0.6928915569760433, 0.5875892857142857, 0.686...
# 4   [0.6944886945063572, 0.5842559523809525, 0.692...
# 5   [0.6908977809551845, 0.5933928571428572, 0.689...
# 6   [0.6721573657428823, 0.5802678571428571, 0.691...
# 7   [0.6850643424870684, 0.5897916666666667, 0.680...
# 8   [0.6754213802094285, 0.5884821428571428, 0.671...
# 9   [0.691393456411119, 0.5630952380952381, 0.6836...
# 10  [0.6850838274668125, 0.5864880952380952, 0.685...
# 11  [0.6879908042109986, 0.5873511904761904, 0.689...
#
#                                                    F1
# 0   [0.6766899214612189, 0.5825007104290991, 0.673...
# 1   [0.6838106973347937, 0.5910893529227443, 0.697...
# 2   [0.6680583446331692, 0.572975650569981, 0.6771...
# 3   [0.6781009344700405, 0.5933218099339673, 0.694...
# 4   [0.6796640726202052, 0.5963125236287876, 0.691...
# 5   [0.6791485996913263, 0.5973978086736998, 0.696...
# 6   [0.6692994397799032, 0.5838897127717003, 0.690...
# 7   [0.6765613430491256, 0.5919061807425912, 0.688...
# 8   [0.6701515151515152, 0.5848452969208856, 0.680...
# 9   [0.6684878962272433, 0.5783828556192375, 0.689...
# 10  [0.678982737428197, 0.5903817389060695, 0.6870...
# 11  [0.6768688466822701, 0.5911898317534936, 0.695...

# %%
rf_r = RandomForestClassifier()
rf_results_r = test_model(rf_r, params_rf, Xr_train, yr_train, 4)
# Out:
# Testing {'criterion': 'entropy', 'max_features': None, 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': None, 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': None, 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': None, 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': None, 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': None, 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4

# %%
rf_results_r
# Out:
#                                            Parameters  Accuracy  \
# 0   {'criterion': 'entropy', 'max_features': None,...  0.648230
# 1   {'criterion': 'entropy', 'max_features': None,...  0.652655
# 2   {'criterion': 'entropy', 'max_features': None,...  0.657080
# 3   {'criterion': 'entropy', 'max_features': 'sqrt...  0.654867
# 4   {'criterion': 'entropy', 'max_features': 'sqrt...  0.664823
# 5   {'criterion': 'entropy', 'max_features': 'sqrt...  0.655973
# 6   {'criterion': 'gini', 'max_features': None, 'n...  0.660398
# 7   {'criterion': 'gini', 'max_features': None, 'n...  0.653761
# 8   {'criterion': 'gini', 'max_features': None, 'n...  0.650442
# 9   {'criterion': 'gini', 'max_features': 'sqrt', ...  0.643805
# 10  {'criterion': 'gini', 'max_features': 'sqrt', ...  0.651549
# 11  {'criterion': 'gini', 'max_features': 'sqrt', ...  0.653761
#
#                                             Precision  \
# 0   [0.6993019169442029, 0.5769397510229638, 0.627...
# 1   [0.7088564561344306, 0.5767560664112388, 0.640...
# 2   [0.7164175792513288, 0.5840703748542732, 0.635...
# 3   [0.7096816028192232, 0.5762794260839682, 0.633...
# 4   [0.721996095737198, 0.5857289227166277, 0.6413...
# 5   [0.711087004217352, 0.5836257012395734, 0.6348...
# 6   [0.710973667442442, 0.5929204040675975, 0.6322...
# 7   [0.7084939957265656, 0.5749923725922617, 0.628...
# 8   [0.7088002473589098, 0.5694743739811395, 0.635...
# 9   [0.7086472868223307, 0.5519606167194957, 0.620...
# 10    [0.7075486834863407, 0.5772654826958106, 0.625]
# 11  [0.7099677167062477, 0.56965587715422, 0.64881...
#
#                                                Recall  \
# 0   [0.7665440181503266, 0.507965367965368, 0.5935...
# 1   [0.7693416672680691, 0.5167965367965368, 0.593...
# 2   [0.762352430868786, 0.5336580086580087, 0.6031...
# 3   [0.7733007749070833, 0.518961038961039, 0.5871...
# 4   [0.782770984435704, 0.5322077922077921, 0.5937...
# 5   [0.7667928484225213, 0.5228354978354979, 0.605...
# 6   [0.7985606183620202, 0.493008658008658, 0.5996...
# 7   [0.7827307656454852, 0.5068831168831169, 0.579...
# 8   [0.7668770447683999, 0.5133766233766234, 0.591...
# 9   [0.76214381938681, 0.5022943722943722, 0.58748...
# 10  [0.7667526296323025, 0.5148051948051948, 0.594...
# 11  [0.7667086520766426, 0.5128354978354979, 0.611...
#
#                                                    F1
# 0   [0.7287268290550252, 0.5365429254138933, 0.603...
# 1   [0.7340462090488735, 0.5408207295721544, 0.609...
# 2   [0.7345557238681586, 0.552944507564733, 0.6152...
# 3   [0.7378252467152872, 0.5427309136587548, 0.605...
# 4   [0.7489290010191658, 0.554555734629146, 0.6139...
# 5   [0.7353974423173503, 0.5471840027718353, 0.616...
# 6   [0.7495656658703047, 0.5324544926787724, 0.612...
# 7   [0.7413589466422614, 0.5356259714235461, 0.599...
# 8   [0.7337943930426167, 0.5354384395694065, 0.609...
# 9   [0.7315246138822192, 0.5224111452391399, 0.599...
# 10  [0.7335396437686826, 0.5409753460255425, 0.605...
# 11  [0.734404689802491, 0.5346268368168453, 0.6267...

# %%
params_knn = {'n_neighbors' : (1, 3, 5, 7, 9),
             'metric' : ('minkowski', 'euclidean', 'manhattan', 'cosine')}
knn = KNeighborsClassifier()
knn_results_o = test_model(knn, params_knn, Xo_train, yo_train, 4)
# Out:
# Testing {'metric': 'minkowski', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4

# %%
knn_results_o
# Out:
#                                    Parameters  Accuracy  \
# 0   {'metric': 'minkowski', 'n_neighbors': 1}  0.618889
# 1   {'metric': 'minkowski', 'n_neighbors': 3}  0.660000
# 2   {'metric': 'minkowski', 'n_neighbors': 5}  0.680000
# 3   {'metric': 'minkowski', 'n_neighbors': 7}  0.676667
# 4   {'metric': 'minkowski', 'n_neighbors': 9}  0.690000
# 5   {'metric': 'euclidean', 'n_neighbors': 1}  0.618889
# 6   {'metric': 'euclidean', 'n_neighbors': 3}  0.660000
# 7   {'metric': 'euclidean', 'n_neighbors': 5}  0.680000
# 8   {'metric': 'euclidean', 'n_neighbors': 7}  0.676667
# 9   {'metric': 'euclidean', 'n_neighbors': 9}  0.690000
# 10  {'metric': 'manhattan', 'n_neighbors': 1}  0.624444
# 11  {'metric': 'manhattan', 'n_neighbors': 3}  0.656667
# 12  {'metric': 'manhattan', 'n_neighbors': 5}  0.676667
# 13  {'metric': 'manhattan', 'n_neighbors': 7}  0.668889
# 14  {'metric': 'manhattan', 'n_neighbors': 9}  0.691111
# 15     {'metric': 'cosine', 'n_neighbors': 1}  0.610000
# 16     {'metric': 'cosine', 'n_neighbors': 3}  0.667778
# 6   [0.6838005006087506, 0.592954651292571, 0.6983...
# 7   [0.7095715474782983, 0.5942313334629621, 0.735...
# 8   [0.6991941022568557, 0.5810153120379857, 0.747...
# 9   [0.6983783249395534, 0.6001657883179623, 0.769...
# 10  [0.6429224001325444, 0.5746061959687724, 0.649...
# 11  [0.6795841145621042, 0.586301861873916, 0.7005...
# 12  [0.702556382504605, 0.5911042806864044, 0.7346...
# 13  [0.6921245058577273, 0.5710548312884242, 0.742...
# 14  [0.7013130896078873, 0.5979556839182605, 0.772...
# 15  [0.6262050631676503, 0.5587348695918397, 0.638...
# 16  [0.6937464011024518, 0.5949861722740405, 0.708...
# 17  [0.7075549534981583, 0.6028307128863386, 0.745...
# 18  [0.6950460357749606, 0.5798470549167031, 0.758...
# 19  [0.7015130427747844, 0.6053659794225832, 0.767...

# %%
knn_r = KNeighborsClassifier()
knn_results_r = test_model(knn_r, params_knn, Xr_train, yr_train, 4)
# Out:
# Testing {'metric': 'minkowski', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4

# %%
knn_results_r
# Out:
#                                    Parameters  Accuracy  \
# 0   {'metric': 'minkowski', 'n_neighbors': 1}  0.612832
# 1   {'metric': 'minkowski', 'n_neighbors': 3}  0.637168
# 2   {'metric': 'minkowski', 'n_neighbors': 5}  0.648230
# 3   {'metric': 'minkowski', 'n_neighbors': 7}  0.662611
# 4   {'metric': 'minkowski', 'n_neighbors': 9}  0.660398
# 5   {'metric': 'euclidean', 'n_neighbors': 1}  0.612832
# 6   {'metric': 'euclidean', 'n_neighbors': 3}  0.637168
# 7   {'metric': 'euclidean', 'n_neighbors': 5}  0.648230
# 8   {'metric': 'euclidean', 'n_neighbors': 7}  0.662611
# 9   {'metric': 'euclidean', 'n_neighbors': 9}  0.660398
# 10  {'metric': 'manhattan', 'n_neighbors': 1}  0.612832
# 11  {'metric': 'manhattan', 'n_neighbors': 3}  0.639381
# 12  {'metric': 'manhattan', 'n_neighbors': 5}  0.657080
# 13  {'metric': 'manhattan', 'n_neighbors': 7}  0.659292
# 14  {'metric': 'manhattan', 'n_neighbors': 9}  0.663717
# 15     {'metric': 'cosine', 'n_neighbors': 1}  0.601770
# 16     {'metric': 'cosine', 'n_neighbors': 3}  0.637168
# 17     {'metric': 'cosine', 'n_neighbors': 5}  0.642699
# 18     {'metric': 'cosine', 'n_neighbors': 7}  0.658186
# 19     {'metric': 'cosine', 'n_neighbors': 9}  0.667035
#
#                                             Precision  \
# 0   [0.6821273357032176, 0.5231722285164967, 0.583...
# 1   [0.6768200270794986, 0.5500853466386555, 0.670...
# 2   [0.6878831086391392, 0.5484318555008211, 0.690...
# 3   [0.706331511073933, 0.5732108307371904, 0.6790...
# 4   [0.6930362400714685, 0.5824703120684893, 0.685...
# 5   [0.6821273357032176, 0.5231722285164967, 0.583...
# 6   [0.6768200270794986, 0.5500853466386555, 0.670...
# 7   [0.6878831086391392, 0.5484318555008211, 0.690...
# 18  [0.7391565074395401, 0.5236048839417988, 0.647...
# 19  [0.7510280288735848, 0.5223644666984093, 0.654...

# %%
params_lr = {'penalty' : ('l1', 'l2', 'elasticnet', None),
            'C' : (0.1, 1, 10, 100),
            'solver' : ('lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'),
            'max_iter' : [500]}

lr = LogisticRegression()
lr_results_o = test_model(lr, params_lr, Xo_train, yo_train, 4)
# Out:
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cg'}
# 	Fold 1 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=9.96794e-18): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=1.05928e-16): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=6.49198e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=3.77845e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=6.02451e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=3.83533e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.4757e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.4757e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.4757e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=9.96794e-18): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=1.05928e-16): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=6.49198e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=3.77845e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=6.02451e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=3.83533e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.4757e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.4757e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.4757e-17): result may not be accurate.
#   warnings.warn(
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# 	Fold 1 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=9.96794e-18): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=1.05928e-16): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=6.49198e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=3.77845e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=6.02451e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=3.83533e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.4757e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.4757e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.4757e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=9.96794e-18): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=1.05928e-16): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=6.49198e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #2. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=3.77845e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=6.02451e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=3.83533e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.4757e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.4757e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.4757e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(

# %%
lr_results_o
# Out:
#                                            Parameters  Accuracy  \
# 0   {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', '...  0.723333
# 1   {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', '...  0.716667
# 2   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.716667
# 3   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.721111
# 4   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.716667
# 5   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.720000
# 6   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.716667
# 7   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.716667
# 8   {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.715556
# 9   {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.715556
# 10  {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.718889
# 11  {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.715556
# 12  {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.715556
# 13  {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'so...  0.725556
# 14  {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'so...  0.715556
# 15  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.715556
# 16  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.723333
# 17  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.715556
# 18  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.723333
# 19  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.715556
# 20  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.715556
# 21  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.715556
# 22  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.715556
# 23  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.718889
# 24  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.715556
# 25  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.715556
# 26  {'C': 10, 'max_iter': 500, 'penalty': 'l1', 's...  0.725556
# 27  {'C': 10, 'max_iter': 500, 'penalty': 'l1', 's...  0.715556
# 28  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.715556
# 29  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.724444
# 30  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.715556
# 31  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.723333
# 32  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.715556
# 33  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.715556
# 34  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.715556
# 35  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.715556
# 36  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.718889
# 37  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.715556
# 38  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.715556
# 39  {'C': 100, 'max_iter': 500, 'penalty': 'l1', '...  0.723333
# 40  {'C': 100, 'max_iter': 500, 'penalty': 'l1', '...  0.715556
# 41  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.715556
# 42  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.723333
# 43  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.715556
# 44  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.723333
# 45  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.715556
# 46  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.715556
# 47  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.715556
# 48  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.715556
# 49  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.718889
# 50  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.715556
# 51  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.715556
#
#                                             Precision  \
# 0   [0.7196672346786471, 0.6655947614280948, 0.794...
# 1   [0.7203072827534791, 0.6478278665778666, 0.798...
# 2   [0.7219857902723501, 0.6471741347071817, 0.798...
# 3   [0.7196672346786471, 0.6609567901234568, 0.792...
# 4   [0.7219857902723501, 0.6471741347071817, 0.798...
# 5   [0.7196672346786471, 0.657461326788636, 0.7946...
# 6   [0.7219857902723501, 0.6471741347071817, 0.798...
# 7   [0.7219857902723501, 0.6471741347071817, 0.798...
# 8   [0.7219857902723501, 0.6462637705615234, 0.795...
# 9   [0.7219857902723501, 0.6462637705615234, 0.795...
# 10  [0.7230209869597206, 0.6535401002506266, 0.790...
# 11  [0.7219857902723501, 0.6462637705615234, 0.795...
# 12  [0.7219857902723501, 0.6462637705615234, 0.795...
# 13  [0.7282653042692, 0.6640958141509126, 0.794963...
# 14  [0.7219857902723501, 0.6462637705615234, 0.795...
}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #3. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=5.86668e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=4.40618e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #3. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=8.07926e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(

# %%
lr_results_r
# Out:
#                                            Parameters  Accuracy  \
# 0   {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', '...  0.707965
# 1   {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', '...  0.705752
# 2   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.706858
# 3   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.706858
# 4   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.706858
# 5   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.706858
# 6   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.706858
# 7   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.706858
# 8   {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.706858
# 9   {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.706858
# 10  {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.706858
# 11  {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.706858
# 12  {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.706858
# 13  {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'so...  0.707965
# 14  {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'so...  0.706858
# 15  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.706858
# 16  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.707965
# 17  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.706858
# 18  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.707965
# 19  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.706858
# 20  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.706858
# 21  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.706858
# 22  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.706858
# 23  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.706858
# 24  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.706858
# 25  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.706858
# 26  {'C': 10, 'max_iter': 500, 'penalty': 'l1', 's...  0.707965
# 27  {'C': 10, 'max_iter': 500, 'penalty': 'l1', 's...  0.706858
# 28  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.706858
# 29  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.707965
# 30  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.706858
# 31  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.707965
# 32  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.706858
# 33  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.706858
# 34  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.706858
# 35  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.706858
# 36  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.706858
# 37  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.706858
# 38  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.706858
# 39  {'C': 100, 'max_iter': 500, 'penalty': 'l1', '...  0.707965
# 40  {'C': 100, 'max_iter': 500, 'penalty': 'l1', '...  0.706858
# 41  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.706858
# 42  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.707965
# 43  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.706858
# 44  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.707965
# 45  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.706858
# 46  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.706858
# 47  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.706858
# 48  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.706858
# 49  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.706858
# 50  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.706858
# 51  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.706858
#
#                                             Precision  \
# 0   [0.7347092290096483, 0.6621836677741881, 0.692...
# 1   [0.7347092290096483, 0.6559548337151654, 0.688...
# 2   [0.737348021296885, 0.6547321972002433, 0.6903...
# 3   [0.7347092290096483, 0.6590994878032157, 0.690...
# 4   [0.737348021296885, 0.6547321972002433, 0.6903...
